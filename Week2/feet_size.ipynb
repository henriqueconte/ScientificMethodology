# %% [markdown]
# # Getting the (wrong) picture from the data

# %% [markdown]
# ## Data

# %%
feet_size = c(17.5, 17.5, 17.5, 17.5, 18, 18, 18, 18, 18.5, 18.5, 18.5, 19, 19, 20, 20, 20, 20.5, 20.5, 20.5, 20.5, 21, 21, 21, 21, 21.5, 21.5, 21.5, 22, 22, 22, 22, 23, 23, 23, 23.5, 23.5, 23.5, 23.5, 24, 24, 24, 24.5, 24.5, 24.5, 24.5, 25, 25, 25, 25, 25.5, 25.5, 26, 26, 26, 26.5, 26.5, 26.5, 27, 27, 27, 27, 27.5, 27.5, 28, 28, 28, 28, 28.5, 28.5, 29, 29, 29)
mistakes = c(15, 18, 19, 20, 16, 17, 18, 19, 14, 16, 17, 15, 16, 13, 14, 15, 12, 13, 14, 15, 10, 11, 13, 15, 10, 12, 13, 8, 10, 11, 12, 8, 9, 10, 7, 8, 9, 11, 6, 8, 9, 6, 7, 8, 10, 4, 6, 7, 8, 5, 6, 4, 5, 7, 3, 4, 5, 2, 3, 4, 7, 2, 3, 0, 1, 2, 4, 0, 2, 0, 1, 2)

feet_mistakes = data.frame(feet_size=feet_size, mistakes=mistakes)
feet_mistakes
# Out:
#    feet_size mistakes
# 1  17.5      15
# 2  17.5      18
# 3  17.5      19
# 4  17.5      20
# 5  18.0      16
# 6  18.0      17
# 7  18.0      18
# 8  18.0      19
# 9  18.5      14
# 10 18.5      16
# 11 18.5      17
# 12 19.0      15
# 13 19.0      16
# 14 20.0      13
# 15 20.0      14
# 16 20.0      15
# 17 20.5      12
# 18 20.5      13
# 19 20.5      14
# 20 20.5      15
# 21 21.0      10
# 22 21.0      11
# 23 21.0      13
# 24 21.0      15
# 25 21.5      10
# 26 21.5      12
# 27 21.5      13
# 28 22.0       8
# 29 22.0      10
# 30 22.0      11
# ⋮  ⋮         ⋮
# 43 24.5       7
# 44 24.5       8
# 45 24.5      10
# 46 25.0       4
# 47 25.0       6
# 48 25.0       7
# 49 25.0       8
# 50 25.5       5
# 51 25.5       6
# 52 26.0       4
# 53 26.0       5
# 54 26.0       7
# 55 26.5       3
# 56 26.5       4
# 57 26.5       5
# 58 27.0       2
# 59 27.0       3
# 60 27.0       4
# 61 27.0       7
# 62 27.5       2
# 63 27.5       3
# 64 28.0       0
# 65 28.0       1
# 66 28.0       2
# 67 28.0       4
# 68 28.5       0
# 69 28.5       2
# 70 29.0       0
# 71 29.0       1
# 72 29.0       2

# %% [markdown]
# ## Graphical representation

# %%
plot(feet_mistakes)
# Out:
# plot without title

# %% [markdown]
# ## Conclusion
#
# As we can see, the number of mistakes decreases as the feet size get bigger. This happens because the students get older, so their feet get naturally bigger.
